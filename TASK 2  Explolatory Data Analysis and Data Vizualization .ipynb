# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS : PHARMA DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Surface Pro\Desktop\ENTRI APP\phython\self_projects\cleaned_pharma.csv')
df.head(1)
# Out:
#        Date              Product Sales Person  Boxes Shipped  Amount ($)  \
# 0  2/6/2022  Pain Relief Tablets  Divya Mehra              7       67.43
#
#      Country  Total Revenue
# 0  Australia         472.01

# %% [markdown]
# #### 1️⃣ TOTAL REVENUE

# %% [markdown]
# #### 🟨 STATISTICAL SUMMARY OF TOTAL REVENUE

# %%
df['Total Revenue'].describe()
# Out:
# count     333.000000
# mean     2457.048859
# std      2405.885021
# min         8.090000
# 25%       397.300000
# 50%      1679.040000
# 75%      4026.450000
# max      9881.600000
# Name: Total Revenue, dtype: float64

# %% [markdown]
# #### 🟨 COUNT OF TOTAL REVENUE

# %%
plt.figure(figsize=(20,8))
sns.histplot(data=df, x= 'Total Revenue', bins = 5)
plt.title('TOTAL REVENUE COUNT', size=20)
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The chart, titled "TOTAL REVENUE COUNT," is a histogram that visualizes the frequency distribution of the "Total Revenue" variable. The x-axis shows the range of revenue, and the y-axis shows the count (or frequency) of observations that fall into each bin.
#
# Here are the key observations from the histogram:
#
# Highest Frequency: The majority of the data points fall into the first bin, which represents the lowest revenue range (from 0 to approximately 2000). The count for this bin is the highest, at approximately 177. This is also stated in the "INFERENCE" text below the plot.
#
# Decreasing Frequency: As the total revenue increases, the frequency of observations decreases dramatically.
#
# The second bin (from ~2000 to ~4000) has a count of around 70.
#
# The third bin (from ~4000 to ~6000) has a count of around 50.
#
# The fourth bin (from ~6000 to ~8000) has a count of around 25.
#
# The fifth and final bin (from ~8000 to ~10000) has the lowest count, at around 10.
#
# In summary, the histogram shows that the total revenue data is heavily skewed to the right. Most of the revenue values are concentrated in the lower range, with a few instances of very high total revenue. This is a common distribution in sales data, where a large number of small transactions or a few top performers drive the bulk of the revenue.

# %% [markdown]
# #### 🟨 LARGEST TOTAL REVENUE

# %%
lr = df['Total Revenue'].nlargest()
lr
# Out:
# 274    9881.60
# 229    9738.80
# 303    9598.60
# 58     9415.60
# 285    9018.35
# Name: Total Revenue, dtype: float64

# %% [markdown]
# #### 🟨 PERCENTAGE OF 5 LARGEST REVENUE

# %%
plt.figure(figsize=(20,8))
plt.pie(lr, labels=lr, autopct='%1.1f%%')
plt.title('PERCENTAGE OF 5 LARGEST REVENUE' ,size=20)
plt.axis('equal')
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The pie chart, titled "PERCENTAGE OF 5 LARGEST REVENUE," visualizes the proportional distribution of the five largest revenue values. The specific entities associated with these revenues are not labeled, but the numerical revenue values and their corresponding percentages are displayed.
#
# Largest Slice: The slice with the value 9833.6 represents the largest percentage, at 20.7%. This value is likely the highest of the five largest revenues.
#
# Re-examining the chart:
#
# 20.7%: 9833.6 (the largest slice)
#
# 20.4%: 9738.8
#
# 20.1%: 9550.6
#
# 19.8%: 9415.6
#
# 18.9%: 9018.35 (the smallest slice)
#
# The pie chart effectively highlights that even among the top five revenue generators, the contribution is relatively evenly distributed, with the smallest share (18.9%) and the largest share (20.7%) being very close. There is no single entity that dominates the group of the top five.

# %% [markdown]
# #### 🟨 SMALLEST TOTAL REVENUE

# %%
sr = df['Total Revenue'].nsmallest()
sr
# Out:
# 80     8.09
# 109    8.51
# 279    8.77
# 131    9.40
# 24     9.98
# Name: Total Revenue, dtype: float64

# %% [markdown]
# #### 🟨 PERCENTAGE OF SMALLEST REVENUE

# %%
plt.figure(figsize=(20,8))
plt.pie(sr, labels=sr, autopct='%1.1f%%')
plt.title('PERCENTAGE OF SMALLEST REVENUE', size=20)
plt.axis('equal')
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The pie chart, titled "PERCENTAGE OF SMALLEST REVENUE," shows the proportional distribution of the smallest revenue values among different entities. The specific entities are not clearly labeled, but the percentages and values are visible.
#
# #### Largest Slice:
# The slice with the value 9.98 represents the largest percentage, at 22.3%.
#
# #### Second Largest Slice:
# The slice with the value 9.4 is the next largest at 21.0%.
#
# #### Other Slices:
# The remaining slices are relatively similar in size:
#
# The slice with value 8.77 is 19.6%.
#
# The slice with value 9.51 is 18.0%.
#
# The slice with value 8.09 is 19.1%.
#
# The title of the chart, "PERCENTAGE OF SMALLEST REVENUE," is a bit unusual.
# It seems the chart is either plotting the smallest revenue values from the data, or perhaps the proportions of the total revenue that make up the "smallest" portion of the data.
# Given the percentages are all significant (18-22%), it's more likely this chart is showing the distribution of the lowest revenue generators, rather than the smallest values themselves.

# %% [markdown]
# #### 🟨 TOTAL REVENUE OF PRODUCTS

# %%
pt = df.groupby('Product')['Total Revenue'].sum()
pt
# Out:
# Product
# Allergy Pills          103576.67
# Antiseptic Cream       135073.75
# Cough Syrup            118048.63
# Digestive Enzyme       161580.55
# Eye Drops              114050.79
# Nasal Spray            111448.54
# Pain Relief Tablets     74418.34
# Name: Total Revenue, dtype: float64

# %% [markdown]
# #### 🟨 PRODUCT PER REVENUE

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=df, x ='Product', y = 'Total Revenue', color='yellow', errorbar=None)
plt.title('PRODUCT PER REVENUE', size=20)
plt.show()

# %% [markdown]
# The chart, titled "PRODUCT PER REVENUE," compares the total revenue generated by various products.
#
#      🔸 Highest Revenue: The product "Digestive Enzyme Product" has the highest total revenue, reaching a value of approximately 3250.
#
#      🔸 Lowest Revenue: The product "Pain Relief Tablets" has the lowest total revenue, at just over 1500.
#
#      🔸 Other Products: The products "Cough Syrup" and "Antiseptic Cream" also have high revenues, both falling between 2500 and 3000.
#
#      🔸 Products like "Eye Drops," "Nasal Spray," and "Allergy Pills" have revenues that are moderately high but lower than the top-performing products.
#
#      🔸 In short, the "Digestive Enzyme Product" is the top revenue generator among the products shown.

# %% [markdown]
# ### 2️⃣ COUNTRIES

# %% [markdown]
# #### 🟨 VALUE COUNT OF CONTRIES

# %%
c = df['Country'].value_counts()
c
# Out:
# Country
# USA          77
# UK           74
# Canada       65
# India        64
# Australia    53
# Name: count, dtype: int64

# %% [markdown]
# #### 🟨 PERCENTAGE WISE VIZUALS OF CONSUMERS-COUNTRIES

# %%
plt.figure(figsize= (20,8))
plt.pie(c, labels = c.index, autopct='%1.1f%%', startangle=140)
plt.title('PERCENTAGE OF COUNTRY-WISE',size=20)
plt.axis('equal')
plt.show()

# %% [markdown]
# The pie chart, titled "PERCENTAGE OF COUNTRY-WISE," shows the distribution of a value (likely the count of some items) across five different countries:
#
#      🔸 USA: Represents the largest share at 23.1%.
#
#      🔸 Canada: Is the second-largest share at 20.5%.
#
#      🔸 India: Has the third-largest share at 19.2%.
#
#      🔸 UK: Represents 22.2% of the total, making it the second-largest share in terms of raw percentage, although visually it is close to Canada.
#
#      🔸 Australia: Has the smallest share at 15.0%.
#
# The pie chart effectively visualizes the proportions, clearly showing that the USA accounts for the largest portion, while Australia accounts for the smallest.

# %% [markdown]
# #### 🟨 COUNTRY WISE AMOUNT GENERATED

# %%
df.groupby(['Country', 'Amount ($)']).sum(numeric_only=True).reset_index()
# Out:
#        Country  Amount ($)  Boxes Shipped  Total Revenue
# 0    Australia       12.41              1          12.41
# 1    Australia       23.68              1          23.68
# 2    Australia       29.63              2          59.26
# 3    Australia       36.54              3         109.62
# 4    Australia       41.09              5         205.45
# ..         ...         ...            ...            ...
# 328        USA      411.44             18        7405.92
# 329        USA      414.06             20        8281.20
# 330        USA      427.81             20        8556.20
# 331        USA      433.81             20        8676.20
# 332        USA      494.08             20        9881.60
#
# [333 rows x 4 columns]

# %% [markdown]
# #### 🟨 COUNT OF PRODUCT PER COUNTRY

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = df, x = 'Product', hue='Country')
plt.title('COUNT OF PRODUCT PER COUNTRY', fontsize=20)
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The chart, titled "COUNT OF PRODUCT PER COUNTRY," is a grouped bar chart that shows the count of each product sold in different countries. The countries are distinguished by color:
#
#                                           Blue: Australia
#
#                                           Orange: Canada
#
#                                           Green: UK
#
#                                           Red: USA
#
#                                           Purple: India
#
# Here are the key observations from the chart:
#
#         🔸 USA (Red): The USA consistently has a high count for most products. It has the highest count for "Pain Relief Tablets," "Eye Drops," and "Allergy Pills."
#
#         🔸 India (Purple): India also shows a consistently high count for most products, with its count being the highest for "Antiseptic Cream," "Cough Syrup," "Nasal Spray," and "Allergy Pills."
#
#         🔸 UK (Green): The UK's product counts are generally lower than the USA's and India's but are significant. It has the highest count for "Digestive Enzyme Product."
#
#         🔸 Australia (Blue) and Canada (Orange): These two countries generally have the lowest counts for most of the products.
#
# The chart effectively visualizes how the count of each product is distributed across the five countries, revealing that the USA and India are the leading consumers for most of these products.

# %% [markdown]
# #### PIVOT TABLE TOTAL REVENUE GENERATED PER PRODUCT BY SALES PERSON

# %%
pv = df.pivot_table( values = 'Total Revenue', index = 'Sales Person', columns = 'Product', aggfunc = 'sum', fill_value =0)
pv
# Out:
# Product       Allergy Pills  Antiseptic Cream  Cough Syrup  Digestive Enzyme  \
# Sales Person
# Aman Verma         16183.02           6313.62      9558.14          17280.65
# Divya Mehra         6124.70          16483.79      6022.39          15109.34
# Nikhil Batra       26399.31          33392.84     11361.77          11856.40
# Priya Singh        12091.64          28472.37     40136.84          15106.24
# Rajesh Patel       11378.96          36049.30     26168.74          29291.50
# Ritika Shah        15972.49           6982.29     15422.33          40660.40
# Sneha Iyer         15426.55           7379.54      9378.42          32276.02
#
# Product       Eye Drops  Nasal Spray  Pain Relief Tablets
# Sales Person
# Aman Verma     20586.67     22183.13              5210.95
# Divya Mehra     9201.96      8353.37             25175.28
# Nikhil Batra   31112.23     15438.07             17596.34
# Priya Singh     9379.40     21180.51              1495.28
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(pv, annot=True, cmap='coolwarm')
plt.title('TOTAL REVENUE GENERATED PER PRODUCT BY SALES PERSON', size=20)
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The heatmap, titled "TOTAL REVENUE GENERATED PER PRODUCT BY SALES PERSON," visualizes the total revenue generated by each salesperson for each product. The color intensity corresponds to the revenue amount, with darker red indicating higher revenue and darker blue indicating lower revenue.
#
# #### Here are some key observations:
#
# #### Top-Selling Salespeople:
#
#      🔸 Priya Singh: Has a very high revenue from "Cough Syrup" ($46,040), indicated by a very dark red cell. She also has high revenue from "Digestive Enzyme Product."
#
#      🔸 Ritikha Shah: Has the highest revenue overall, a staggering $41,360 from the "Digestive Enzyme Product," also shown in a very dark red cell.
#
# #### Top-Selling Products:
#
#      🔸 Cough Syrup: This product has very high revenue from Priya Singh and Ritikha Shah.
#
#      🔸 Digestive Enzyme Product: This product appears to be a top revenue generator for multiple salespeople, including Ritikha Shah and Priya Singh.
#
# #### Low-Performing Combinations:
#
#     🔸 Sneha Iyer: The revenue for all her products is low, with several values being close to or at zero, indicated by light and dark blue colors. This suggests she is a low performer.
#
#     🔸 Ritikha Shah: While she has a peak performance with "Digestive Enzyme Product," her revenue for "Antiseptic Cream" and "Nasal Spray" is relatively low compared to her other sales.
#
# #### Overall,
#     🔸 the heatmap provides a clear, at-a-glance view of which salespeople are performing best and which products are generating the most revenue. Priya Singh and Ritikha Shah are standout performers, particularly with "Cough Syrup" and "Digestive Enzyme Product."

# %% [markdown]
# #### CALCULATING VALUE COUNTS OF SALES PERSON

# %%
sp = df['Sales Person'].value_counts()
sp
# Out:
# Sales Person
# Rajesh Patel    55
# Priya Singh     54
# Nikhil Batra    52
# Divya Mehra     48
# Aman Verma      45
# Ritika Shah     44
# Sneha Iyer      35
# Name: count, dtype: int64

# %% [markdown]
# #### 🟨 PERCENTAGE OF SALES PERSON

# %%
plt.figure(figsize=(20,8))
plt.pie( sp, labels= sp.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Sales Person', fontsize=20) 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### INFERENCE:
#
# Pie Chart Summary
# The pie chart, titled "Percentage of Sales Person," shows the proportional distribution of a value (likely sales or product count) among six different salespeople.
#
# ### 🔸 Top Performers:
#
#       Priya Singh: With a share of 16.2%, Priya Singh appears to be the top performer among all salespeople.
#
#       Rajesh Patel: Following closely behind is Rajesh Patel, who accounts for 15.5% of the total.
#
# ### 🔸 Mid-Range Performers:
#
#       Divya Mehra: Has a share of 14.4%.
#
#       Aman Verma: Accounts for 13.5%.
#
#       Ritikha Shah: Has a share of 13.2%.
#
# ### 🔸 Lowest Performer:
#
#       Nikhil Batra: With 10.6%, Nikhil Batra has the smallest share.
#
# This updated summary reflects the percentages more accurately. The chart clearly shows that Rajesh Patel and Priya Singh are the top contributors, while Sneha Iyer and Nikhil Batra contribute the least.

# %% [markdown]
# #### 🟨 TOTAL SALES DONE BY SALES MAN

# %%
sa = df.groupby('Sales Person')['Amount ($)'].sum()
sa
# Out:
# Sales Person
# Aman Verma       7039.07
# Divya Mehra      6896.15
# Nikhil Batra    10416.34
# Priya Singh      9121.78
# Rajesh Patel    11023.53
# Ritika Shah      7945.97
# Sneha Iyer       6486.45
# Name: Amount ($), dtype: float64

# %% [markdown]
# ### 🟨  TOTAL REVENUE GENERATED BY SALES MAN PER PRODUCTS

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=df, x='Sales Person', y='Total Revenue', hue='Product', errorbar=None)
plt.title('TOTAL REVENUE GENERATED BY SALES MAN PER PRODUCTS', size=20)
plt.show()

# %% [markdown]
# ### INFERENCE:
#
# The chart, titled "TOTAL REVENUE GENERATED BY SALES MAN PER PRODUCTS," is a grouped bar chart that shows the total revenue generated by each salesperson for different products. The products are distinguished by color, with a legend on the right side of the chart.
#
# ### Here are the key observations:
#
# #### Top-Performing Salespeople:
#
# Rajesh Patel: Appears to be a top performer, with high revenues from "Digestive Enzyme Product" (red bar) and "Pain Relief Tablets" (purple bar), both reaching above 4000.
#
# Sneha Iyer: Also shows strong performance, particularly with "Digestive Enzyme Product," where her revenue is very high, close to 4500.
#
# #### Standout Products:
#
# Digestive Enzyme Product (red): This product seems to be a high-revenue generator, with particularly strong sales from Sneha Iyer and Rajesh Patel.
#
# Pain Relief Tablets (purple): This product also generates high revenue, especially for Rajesh Patel and Nikhil Batra.
#
# #### Overall Performance:
#
#     Divya Mehra: Her revenue for all products appears to be consistently in the lower range compared to her colleagues, typically below 2500.
#
#     Ritikha Shah: Shows a mixed performance. Her revenue for "Digestive Enzyme Product" is good, but her other product revenues are lower.
#
#     Nikhil Batra: Performs well with "Pain Relief Tablets" and "Antiseptic Cream," but his other revenues are lower.
#
#     Aman Verma: His revenue is generally in the middle range for most products, with no single product standing out as a very high earner.
#
# In summary, the chart effectively highlights which salespeople are the top performers and identifies which products are their biggest sources of revenue. Rajesh Patel and Sneha Iyer are the most successful, driven by strong sales of "Digestive Enzyme Product" and "Pain Relief Tablets."

# %% [markdown]
# #### 🟨 BOXES SHIPED PER PRODUCTS

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=df, x='Product', y='Boxes Shipped', color='brown', errorbar=None)
plt.title('BOXES SHIPED PER PRODUCTS', size=20)
plt.xlabel('PRODUCTS' , size=15)
plt.ylabel('BOXES SHIPPED', size=15)
plt.show()

# %% [markdown]
# ### INFERENCE:
# The chart, titled "BOXES SHIPED PER PRODUCTS," is a simple bar chart that compares the number of boxes shipped for different products.
#
# #### Highest Shipped:
#     The products "Cough Syrup" and "Digestive Enzyme Products" have the highest number of boxes shipped, both at approximately 12. This suggests they are the most popular or in-demand products in terms of volume.
#
# #### Lowest Shipped:
#     The product "Eye Drops" has the lowest number of boxes shipped, at slightly less than 10.
#
# #### Other Products:
#     "Antiseptic Cream," "Nasal Spray," and "Allergy Pills" all have a similar number of boxes shipped, hovering around 10 to 11. "Pain Relief Tablets" is slightly lower, at around 9 boxes.
#
# In summary, the chart clearly shows that "Cough Syrup" and "Digestive Enzyme Products" are the top-selling items when measured by the number of boxes shipped.

# %% [markdown]
# #### 🟨 FINDING CO-RELATION BETWEEN BOXES SHIPPED AND AMOUNT

# %%
df['Boxes Shipped'].corr(df['Amount ($)'])
# Out:
# 0.8536191788625589

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data=df, x='Boxes Shipped', y='Amount ($)', color='lime')
plt.title('BOXES SHIPPED PER AMOUNT', size=20)
plt.show()

# %% [markdown]
# #### INFERENCE:
# The chart, titled "BOXES SHIPPED PER AMOUNT," is a series of box plots that visualize the distribution of "Amount ($)" for each distinct value of "Boxes Shipped."
#
# #### Here are the key observations from the box plots:
#
# Increasing Trend: There is a clear positive correlation between the number of boxes shipped and the amount. As the number of boxes shipped increases (moving from left to right on the x-axis), the median, interquartile range (IQR), and overall distribution of the "Amount ($)" all tend to increase.
#
# #### Distribution and Variability:
#
# For a small number of boxes shipped (e.g., 1 to 5), the amount is low, and the variability (the size of the box) is also small.
#
# As the number of boxes shipped increases, the median amount (the line inside the box) goes up significantly.
#
# The spread of the data, as shown by the size of the box and the whiskers, also generally increases with the number of boxes shipped. This indicates that for a higher number of boxes shipped, the revenue can be more variable.
#
# #### Specific Observations:
#
# The box plot for "Boxes Shipped" at a count of 20 has the highest median and the largest range, with amounts distributed well above $200.
#
# The box plot for a count of 1 has a very low median and a tight distribution, with amounts below $50.
#
# In summary, the chart effectively demonstrates a strong positive relationship: a higher number of boxes shipped is consistently associated with a higher revenue amount. The plot also gives a sense of the distribution and variability of the revenue for each shipping count.

# %% [markdown]
# #### 🟨 CO-RELATION OF NUMERICAL DATA

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                Boxes Shipped  Amount ($)  Total Revenue
# Boxes Shipped       1.000000    0.853619       0.883289
# Amount ($)          0.853619    1.000000       0.967235
# Total Revenue       0.883289    0.967235       1.000000

# %%
plt.figure(figsize=(15,6))
sns.heatmap(corr, annot=True)
plt.title('CO-RELATION MATRIX', size=20)
plt.show()

# %% [markdown]
# #### INFERENCE:
# The heatmap, titled "CO-RELATION MATRIX," visualizes the pairwise correlation between three numerical variables: "Boxes Shipped," "Amount ($)," and "Total Revenue." The color intensity and the annotated values indicate the strength and direction of the linear relationship between the variables.
#
# Here are the key observations from the heatmap:
#
# #### Perfect Correlation (1):
#     As expected, the diagonal of the matrix shows a perfect positive correlation of 1.00. This is because a variable is always perfectly correlated with itself.
#
# #### Strong Positive Correlations:
#
# #### "Amount ($)" and "Total Revenue":
#      The correlation coefficient between these two variables is 0.97. This is an extremely strong positive correlation, which makes sense. Higher amounts per transaction would naturally lead to higher total revenue.
#
# #### "Boxes Shipped" and "Total Revenue":
#      The correlation coefficient is 0.88. This is a very strong positive correlation, suggesting that as more boxes are shipped, the total revenue tends to be significantly higher.
#
# #### "Boxes Shipped" and "Amount ($)":
#     The correlation coefficient is 0.85. This also indicates a very strong positive correlation. A higher number of boxes shipped is strongly associated with a higher amount (likely due to the total value of the goods).
#
# In summary,
#       The heatmap confirms that all three variables are very strongly and positively correlated with each other.
#       The relationship is strongest between "Amount()"and"TotalRevenue(0.97),followed by"BoxesShipped"and"TotalRevenue(0.88).
#       The correlation between"BoxesShipped"and"Amount()" is also very high (0.85).
#       This suggests that all three metrics move in tandem, and increasing one will likely increase the others.

# %% [markdown]
# ### 🟨 TOTAL REVENUE GENERATED BY PRODUCTS PER COUNTRY

# %%
pv = df.pivot_table(values='Total Revenue', index='Country', columns='Product',  aggfunc = 'sum', fill_value =0)
pv
# Out:
# Product    Allergy Pills  Antiseptic Cream  Cough Syrup  Digestive Enzyme  \
# Country
# Australia       17559.74          14448.35     20226.75          20504.38
# Canada          11427.13          33448.89     13665.81          47647.84
# India           30672.98          34521.65     13694.21          31713.01
# UK              13827.13          20482.79     43840.51          35013.72
# USA             30089.69          32172.07     26621.35          26701.60
#
# Product    Eye Drops  Nasal Spray  Pain Relief Tablets
# Country
# Australia   20576.43     30319.04             17967.56
# Canada      24680.32     18938.19             15651.98
# India       19954.57     10537.79             11180.03
# UK          17652.11     30745.25              6789.57
# USA         31187.36     20908.27             22829.20

# %%
plt.figure(figsize=(15,8))
sns.heatmap(pv, annot=True, cmap='coolwarm')
plt.title(' TOTAL REVENUE GENERATED BY PRODUCTS PER COUNTRY', size=20)
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The heatmap, titled "TOTAL REVENUE GENERATED BY PRODUCTS PER COUNTRY," visualizes the total revenue generated by different products in various countries. The rows represent countries, the columns represent products, and the color intensity of each cell indicates the revenue amount, with darker red being the highest and darker blue being the lowest.
#
# #### Here are the key observations from the heatmap:
#
# #### Top-Performing Combinations:
#
# Canada & Digestive Enzyme Product: This combination has the highest revenue of $48,000, indicated by the darkest red cell.
#
# UK & Cough Syrup: This combination also shows very high revenue at $44,000.
#
# India & Antiseptic Cream: This combination has a high revenue of $35,000.
#
# #### Top-Performing Countries (Overall):
#
# India and UK: Both countries have multiple products with high revenue, suggesting they are strong markets.
#
# USA: Has a decent revenue stream across most products, with several values above $25,000.
#
# #### Low-Performing Combinations:
#
# UK & Pain Relief Tablets: This combination has one of the lowest revenues at $6,803.
#
# Australia & Pain Relief Tablets: This is also a low-performing combination with $18,400.
#
# India & Nasal Spray: This combination has a low revenue of $11,000.
#
# #### Overall Observations:
#
# "Digestive Enzyme Product" and "Cough Syrup" seem to be the top revenue-generating products, with high sales in multiple countries.
#
# "Pain Relief Tablets" and "Nasal Spray" appear to be lower revenue-generating products compared to the others.
#
# The heatmap provides a clear, at-a-glance view of which products are most successful in each country, highlighting the specific country-product combinations that drive the most revenue.

# %% [markdown]
# #### 🟨 MONTHLY TRENDS OF ALLERGY PILLS BASED ON COUNTRIES

# %%
monthly_trend = df[df['Product'] == 'Allergy Pills'].groupby(df['Date'].dt.to_period('M'))['Country'].count()
monthly_trend
# Out:
# Date
# 2022-01     4
# 2022-02     3
# 2022-03     6
# 2022-04     5
# 2022-05     8
# 2022-06     9
# 2022-07    10
# 2022-08     5
# Freq: M, Name: Country, dtype: int64

# %%
monthly_trend.plot(kind='line', marker='o',figsize=(15,8), color='red')
plt.title('MONTHLY TRENDS OF ALLERGY PILLS BASED ON COUNTRIES', size=18)
plt.ylabel('NUMBER OF ALLERGY PILLS', size=15)
plt.xlabel('MONTHLY TRENDS', size=15)
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The chart, titled "MONTHLY TRENDS OF ALLERGY PILLS BASED ON COUNTRIES," shows the trend in the number of allergy pills over an eight-month period from January 2022 to August 2022.
#
# #### Here are the key observations from the line plot:
#
# #### Initial Decline:
# The number of allergy pills starts at around 4 in January and drops to its lowest point of approximately 3 in February.
#
# #### Steady Increase:
# Following the low point in February, there is a consistent and strong upward trend. The number of allergy pills increases month-over-month, reaching a peak of around 10 in July. This trend suggests a seasonal increase in the need for allergy medication, which is typical for spring and summer months.
#
# #### Sharp Decline:
# After reaching its peak in July, there is a sharp drop-off in August, with the number of allergy pills falling back to around 5. This marks the end of the peak allergy season.
#
# In summary, the plot clearly illustrates a seasonal pattern for the sale of allergy pills. Sales are lowest at the beginning of the year, rise sharply through the spring and summer, peak in July, and then decline as summer ends.

# %% [markdown]
# #### 🟨 MONTHLY TRENDS OF TOTAL REVENUE

# %%
product_trend = df.groupby(df['Date'].dt.to_period('M'))['Total Revenue'].sum()
product_trend
# Out:
# Date
# 2022-01     72914.03
# 2022-02    101172.45
# 2022-03    105806.71
# 2022-04    104575.93
# 2022-05    124250.06
# 2022-06     95844.07
# 2022-07    126450.89
# 2022-08     87183.13
# Freq: M, Name: Total Revenue, dtype: float64

# %%
product_trend.plot( kind='line', marker='o', figsize=(15,8), color='green')
plt.title('MONTHLY TRENDS OF TOTAL REVENUE', size=15)
plt.xlabel('MONTHLY TRENDS', size=14)
plt.ylabel('TOTAL REVENUE', size=14)
plt.show()

# %% [markdown]
# #### INFERENCE:
#
# The chart, titled "MONTHLY TRENDS OF TOTAL REVENUE," shows how the total revenue has changed over an eight-month period from January to August 2022.
#
# #### Here are the key observations from the line plot:
#
# #### Initial Growth:
# Total revenue starts low in January, at around 75,000, and experiences a significant jump to over 100,000 in February.
#
# #### Stable Period:
# From February to April, the revenue remains relatively stable, hovering just above 100,000, with a slight dip in April.
#
# #### First Peak and Decline:
# There is a sharp increase in revenue, peaking at around 125,000 in May. This is followed by a significant drop in June, with revenue falling to around 95,000.
#
# #### Second Peak and Final Decline:
# Revenue rises again sharply, reaching a new peak of over 125,000 in July. This is the highest revenue point on the chart. Following this peak, there is a very steep drop in August, with revenue plummeting to below 90,000, marking the lowest point since January.
#
# In summary, the total revenue trend shows significant month-to-month volatility with two major peaks in May and July, and corresponding dips in June and August. This pattern suggests a potentially cyclical or seasonal business cycle with high points in late spring/early summer and a significant downturn later in the summer.

# %% [markdown]
# ### CONCLUSION
#
# The analysis of the various graphs reveals a comprehensive picture of the company's market performance in 2022.
#
# A strong, positive correlation exists between all key business metrics:
# Total Revenue, Boxes Shipped, and Amount per order are all highly interdependent.
# The data exhibits a clear seasonal trend, with both Total Revenue and the sales of specific products like Allergy Pills peaking sharply in July before a significant drop in August.
# This pattern suggests a business model that is sensitive to seasonal demand.
#
# Performance is highly uneven across different dimensions.
# Certain products, namely Digestive Enzyme Product and Cough Syrup, are consistently the highest revenue generators and are shipped in the largest volumes.
# The geographic sales performance also varies, with Canada and the UK showing exceptionally high revenues for specific products, while the USA, India, and Australia contribute in a more distributed fashion.
#
# Salesperson performance is similarly segmented. Rajesh Patel, Priya Singh, and Ritikha Shah emerge as top performers, with each excelling in the sales of key products.
# This is in contrast to other salespeople, who contribute a smaller percentage to the total revenue. Finally, a histogram of Total Revenue indicates that while there are a few high-value sales, the majority of transactions fall into the lower revenue brackets.
#
# In conclusion, the company’s success is driven by a small number of top-performing products, concentrated in specific regions during peak seasonal months, and managed by a few key salespeople.

# %% [markdown]
# ### Strategic Solutions for Sales and Revenue Optimization

# %% [markdown]
# Based on the problem definition and the insights from the charts, solving the problem involves a strategic shift from analysis to action. Here is a high-level plan for how to solve the business challenge of optimizing sales and revenue:
#
# ### 1. Capitalize on Strengths
# Top Products: Focus marketing and sales efforts on high-performing products like Digestive Enzyme Product and Cough Syrup. Ensure these products have sufficient inventory and are prominently featured in promotions, especially during their peak seasons.
#
# Top Salespeople: Recognize and reward top-performing salespeople such as Rajesh Patel and Priya Singh. Use their strategies and techniques as a model to train other team members.
#
# ### 2. Optimize Markets and Channels
# Targeted Marketing: Develop specific marketing campaigns for top-performing product-country combinations, such as promoting Digestive Enzyme Product in Canada and Cough Syrup in the UK.
#
# Investigate Underperformance: Conduct a deeper analysis into why certain products, like Pain Relief Tablets, perform poorly in specific markets (e.g., the UK) and either improve their strategy or reallocate resources.
#
# ### 3. Plan for Seasonal Fluctuations
# Seasonal Campaigns: Create robust marketing and inventory plans to fully leverage the peak sales season from May to July.
#
# Mitigation Strategy: Develop a proactive plan to address the sharp drop in sales typically seen in August. This could include end-of-season sales, special promotions, or a focus on non-seasonal products.
#
# ### 4. Address Underperforming Areas
# Salesperson Development: Create a support and training program for salespeople with lower performance, such as Sneha Iyer and Nikhil Batra. This could focus on sales techniques or product knowledge for key revenue drivers.
#
# Transaction Value: Investigate the large number of low-value transactions shown in the histogram. Develop strategies to increase the average order size, such as offering bundles or volume discounts.
#
# ### 5. Plan for Continuous Improvement
# Next Steps in Analysis: Expand the analysis to include the previously excluded data points. Incorporate customer demographics to refine targeting, add cost of goods to measure true profitability, and track marketing campaign data to understand its impact on sales.
#
# Ongoing Monitoring: Establish a regular schedule for analyzing these key performance indicators to ensure strategies remain effective and to quickly identify new trends or issues.
